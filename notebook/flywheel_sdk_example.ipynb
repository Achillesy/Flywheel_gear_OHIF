# %%
import flywheel
from pprint import pprint

# %%
fw = flywheel.Client()

# %%
user_info = fw.get_current_user()
print(f"Firstname: {user_info.firstname} \n"
      f"Lastname: {user_info.lastname} \n"
      f"Email: {user_info.email}")
# Out:
# /mnt/Storage/Xuchu_Liu/miniconda3/envs/tf-2.4.1/lib/python3.8/site-packages/flywheel/flywheel.py:6300: UserWarning: Client version 15.8.0 does not match server version 16.2.4. Please update your client version!
#   warnings.warn('Client version {} does not match server version {}. Please update your client version!'.format(SDK_VERSION, release_version))
# WARNING:Flywheel:Use "pip install flywheel-sdk~=16.2.2" to install a compatible version for this server
# Firstname: Xuchu
# Lastname: Liu
# Email: Xuchu_Liu@rush.edu

# %%
exam_000006_session = fw.get_session('61f008e591188d92013e6c34')
session_metadata = exam_000006_session.info
ohif_metadata = session_metadata['ohifViewer']

# %%
ohif_metadata['measurements']['Length'][1]['description'] = 'A-P Diameter of Vermis'

# %%
exam_000006_session.update_info(session_metadata)

# %%
pprint(ohif_metadata['measurements']['Length'][0])
# Out:
# {'PatientID': '5052559a-0519-4d4b-a5c5-bedf7ee9af0f',
#  'SOPInstanceUID': '1.3.6.1.4.1.9590.100.1.2.197421330710515726636997467353007484258',
#  'SeriesInstanceUID': '1.3.6.1.4.1.9590.100.1.2.130377455213163172923829280602461082065',
#  'StudyInstanceUID': '1.3.6.1.4.1.9590.100.1.2.180543353611215162910272065452027800503',
#  '_id': '507b89a6-dcb4-e0e9-8564-723a5c6f655d',
#  '_measurementServiceId': '069d0546-d19f-c230-9843-d07d95e2f6cc',
#  'active': False,
#  'description': 'Pons',
#  'flywheelOrigin': {'id': 'Xuchu_Liu@rush.edu', 'type': 'user'},
#  'frameIndex': 0,
#  'handles': {'end': {'active': False,
#                      'highlight': True,
#                      'moving': False,
#                      'x': 259.7012048192771,
#                      'y': 238.7277108433735},
#              'start': {'active': False,
#                        'highlight': True,
#                        'x': 282.52530120481936,
#                        'y': 260.31807228915665},
#              'textBox': {'active': False,
#                          'allowedOutsideImage': True,
#                          'boundingBox': {'height': 25,
#                                          'left': 796.6012048192772,
#                                          'top': 395.7722891566265,
#                                          'width': 82.15625},
#                          'drawnIndependently': True,
#                          'hasBoundingBox': True,
#                          'hasMoved': False,
#                          'movesIndependently': False,
#                          'x': 282.52530120481936,
#                          'y': 260.31807228915665}},
#  'imagePath': '1.3.6.1.4.1.9590.100.1.2.180543353611215162910272065452027800503$$$1.3.6.1.4.1.9590.100.1.2.130377455213163172923829280602461082065$$$1.3.6.1.4.1.9590.100.1.2.197421330710515726636997467353007484258$$$0',
#  'invalidated': False,
#  'length': 12.272608750117465,
#  'lesionNamingNumber': 1,
#  'location': 'Brain',
#  'measurementNumber': 1,
#  'timepointId': 'TimepointId',
#  'toolType': 'Length',
#  'userId': '',
#  'uuid': '5e1ba20e-307e-43ab-9745-971fee54bdf8',
#  'viewport': {'displayedArea': {'brhc': {'x': 512, 'y': 512},
#                                 'columnPixelSpacing': 0.390625,
#                                 'presentationSizeMode': 'NONE',
#                                 'rowPixelSpacing': 0.390625,
#                                 'tlhc': {'x': 1, 'y': 1}},
#               'hflip': False,
#               'invert': False,
#               'labelmap': False,
#               'pixelReplication': False,
#               'rotation': 0,
#               'scale': 1.62109375,
#               'translation': {'x': 0, 'y': 0},
#               'vflip': False,
#               'voi': {'windowCenter': 426, 'windowWidth': 888}},
#  'visible': True}

# %%
exam_000006_sessions = fw.sessions()

# %%
fw.sessions.find('label=OHIF_6')[0].id
# Out:
# '61f008e591188d92013e6c34'

# %%
exam_000006_session = fw.get_session('61f008e591188d92013e6c34')
exam_000006_acquisition = exam_000006_session.acquisitions()

# %%
for acquisition in exam_000006_acquisition:
    for file in acquisition.files:
        if file.type == 'dicom':
            print(file)
# Out:
# {'classification': {'Intent': ['Localizer'], 'Measurement': ['T2']},
#  'created': datetime.datetime(2022, 1, 25, 14, 27, 54, 640000, tzinfo=tzutc()),
#  'deid_log_id': None,
#  'file_id': '61f008ea91188d92013e6c63',
#  'hash': None,
#  'id': 'c2ac5143-0d72-467a-ad4e-77d2c13333ea',
#  'info': {},
#  'info_exists': True,
#  'mimetype': 'application/octet-stream',
#  'modality': 'MR',
#  'modified': datetime.datetime(2022, 1, 25, 14, 30, 50, 748000, tzinfo=tzutc()),
#  'name': '1 - Scout Expiration BH.dicom.zip',
#  'origin': {'id': 'Xuchu_Liu@rush.edu',
#             'method': None,
#             'name': None,
#             'type': 'user',
#             'via': None},
#  'parent_ref': {'id': '61f008e591188d92013e6c35', 'type': 'acquisition'},
#  'parents': {'acquisition': '61f008e591188d92013e6c35',
#              'analysis': None,
#              'group': 'fetal',
#              'project': '61b7a25aece9fa9a563d3d26',
#              'session': '61f008e591188d92013e6c34',
#              'subject': '61f008e591188d92013e6c33'},
#  'provider_id': '614cc33343a9d5a4ec99f8e6',
#  'replaced': None,
#  'size': 4085809,
#  'tags': [],
#  'type': 'dicom',
#  'version': 1,
#  'zip_member_count': 18}
# {'classification': {},
#  'created': datetime.datetime(2022, 1, 25, 14, 27, 53, 291000, tzinfo=tzutc()),
#  'deid_log_id': None,
#  'file_id': '61f008e9d5e18dd8fc3e6b69',
#  'hash': None,
#  'id': '8ea6aa33-425c-48ed-b412-d35f5fd3b7e5',
#  'info': {},
#  'info_exists': True,
#  'mimetype': 'application/octet-stream',
#  'modality': 'MR',
#  'modified': datetime.datetime(2022, 1, 25, 14, 30, 37, 219000, tzinfo=tzutc()),
#  'name': '10 - COR Body TRUEFIS BH.dicom.zip',
#  'origin': {'id': 'Xuchu_Liu@rush.edu',
#             'method': None,
#             'name': None,
#             'type': 'user',
#             'via': None},
#  'parent_ref': {'id': '61f008e591188d92013e6c36', 'type': 'acquisition'},
#  'parents': {'acquisition': '61f008e591188d92013e6c36',
#              'analysis': None,
#              'group': 'fetal',
#              'project': '61b7a25aece9fa9a563d3d26',
#              'session': '61f008e591188d92013e6c34',
#              'subject': '61f008e591188d92013e6c33'},
#  'provider_id': '614cc33343a9d5a4ec99f8e6',
#  'replaced': None,
#  'size': 3026952,
#  'tags': [],
#  'type': 'dicom',
#  'version': 1,
#  'zip_member_count': 12}
# {'classification': {},
#  'created': datetime.datetime(2022, 1, 25, 14, 27, 54, 38000, tzinfo=tzutc()),
#  'deid_log_id': None,
#  'file_id': '61f008ea07b3634c5f3e69d3',
#  'hash': None,
#  'id': '65b68ca4-4f6b-478c-8e11-34138c6007d7',
#  'info': {},
#  'info_exists': True,
#  'mimetype': 'application/octet-stream',
#  'modality': 'MR',
#  'modified': datetime.datetime(2022, 1, 25, 14, 30, 45, 468000, tzinfo=tzutc()),
#  'name': '11 - AXIAL BRAIN TRUEFIS BH4MM.dicom.zip',
#  'origin': {'id': 'Xuchu_Liu@rush.edu',
#             'method': None,
#             'name': None,
#             'type': 'user',
#             'via': None},
#  'parent_ref': {'id': '61f008e591188d92013e6c37', 'type': 'acquisition'},
#  'parents': {'acquisition': '61f008e591188d92013e6c37',
#              'analysis': None,
#              'group': 'fetal',
#              'project': '61b7a25aece9fa9a563d3d26',
#              'session': '61f008e591188d92013e6c34',
#              'subject': '61f008e591188d92013e6c33'},
#  'provider_id': '614cc33343a9d5a4ec99f8e6',
#  'replaced': None,
#  'size': 4342741,
#  'tags': [],
#  'type': 'dicom',
#  'version': 1,
#  'zip_member_count': 16}
# {'classification': {},
#  'created': datetime.datetime(2022, 1, 25, 14, 27, 51, 686000, tzinfo=tzutc()),
#  'deid_log_id': None,
#  'file_id': '61f008e7d5e18dd8fc3e6b65',
#  'hash': None,
#  'id': 'e35ab30b-faad-4c13-ba88-2c5e0831566e',
#  'info': {},
#  'info_exists': True,
#  'mimetype': 'application/octet-stream',
#  'modality': 'MR',
#  'modified': datetime.datetime(2022, 1, 25, 14, 30, 35, 434000, tzinfo=tzutc()),
#  'name': '12 - AXIAL BRAIN TRUEFIS BH4MM.dicom',
#  'origin': {'id': 'Xuchu_Liu@rush.edu',
#             'method': None,
#             'name': None,
#             'type': 'user',
#             'via': None},
#  'parent_ref': {'id': '61f008e591188d92013e6c38', 'type': 'acquisition'},
#  'parents': {'acquisition': '61f008e591188d92013e6c38',
#              'analysis': None,
#              'group': 'fetal',
#              'project': '61b7a25aece9fa9a563d3d26',
#              'session': '61f008e591188d92013e6c34',
#              'subject': '61f008e591188d92013e6c33'},
#  'provider_id': '614cc33343a9d5a4ec99f8e6',
#  'replaced': None,
#  'size': 275610,
#  'tags': [],
#  'type': 'dicom',
#  'version': 1,
#  'zip_member_count': 1}
# {'classification': {},
#  'created': datetime.datetime(2022, 1, 25, 14, 27, 53, 579000, tzinfo=tzutc()),
#  'deid_log_id': None,
#  'file_id': '61f008e991188d92013e6c55',
#  'hash': None,
#  'id': '1d5e96a9-f240-4e4d-a013-2e176a74e36d',
#  'info': {},
#  'info_exists': True,
#  'mimetype': 'application/octet-stream',
#  'modality': 'MR',
#  'modified': datetime.datetime(2022, 1, 25, 14, 30, 39, 816000, tzinfo=tzutc()),
#  'name': '13 - AXIAL BRAIN TRUEFIS BH4MM.dicom.zip',
#  'origin': {'id': 'Xuchu_Liu@rush.edu',
#             'method': None,
#             'name': None,
#             'type': 'user',
#             'via': None},
#  'parent_ref': {'id': '61f008e591188d92013e6c39', 'type': 'acquisition'},
#  'parents': {'acquisition': '61f008e591188d92013e6c39',
#              'analysis': None,
#              'group': 'fetal',
#              'project': '61b7a25aece9fa9a563d3d26',
#              'session': '61f008e591188d92013e6c34',
#              'subject': '61f008e591188d92013e6c33'},
#  'provider_id': '614cc33343a9d5a4ec99f8e6',
#  'replaced': None,
#  'size': 4465985,
#  'tags': [],
#  'type': 'dicom',
#  'version': 1,
#  'zip_member_count': 16}
# {'classification': {'Intent': ['Localizer'], 'Measurement': ['T2']},
#  'created': datetime.datetime(2022, 1, 25, 14, 27, 54, 100000, tzinfo=tzutc()),
#  'deid_log_id': None,
#  'file_id': '61f008eab8cb2071843e6968',
#  'hash': None,
#  'id': '174030d2-c4f9-497f-b2fb-7dd543811886',
#  'info': {},
#  'info_exists': True,
#  'mimetype': 'application/octet-stream',
#  'modality': 'MR',
#  'modified': datetime.datetime(2022, 1, 25, 14, 30, 46, 283000, tzinfo=tzutc()),
#  'name': '14 - Scout Expiration BH.dicom.zip',
#  'origin': {'id': 'Xuchu_Liu@rush.edu',
#             'method': None,
#             'name': None,
#             'type': 'user',
#             'via': None},
#  'parent_ref': {'id': '61f008e591188d92013e6c3a', 'type': 'acquisition'},
#  'parents': {'acquisition': '61f008e591188d92013e6c3a',
#              'analysis': None,
#              'group': 'fetal',
#              'project': '61b7a25aece9fa9a563d3d26',
#              'session': '61f008e591188d92013e6c34',
#              'subject': '61f008e591188d92013e6c33'},
#  'provider_id': '614cc33343a9d5a4ec99f8e6',
#  'replaced': None,
#  'size': 4095387,
#  'tags': [],
#  'type': 'dicom',
#  'version': 1,
#  'zip_member_count': 18}
# {'classification': {},
#  'created': datetime.datetime(2022, 1, 25, 14, 27, 53, 963000, tzinfo=tzutc()),
#  'deid_log_id': None,
#  'file_id': '61f008e9d5e18dd8fc3e6b6c',
#  'hash': None,
#  'id': 'ad8bb08e-2d22-4f1e-b91d-5a1d3e310c95',
#  'info': {},
#  'info_exists': True,
#  'mimetype': 'application/octet-stream',
#  'modality': 'MR',
#  'modified': datetime.datetime(2022, 1, 25, 14, 30, 44, 532000, tzinfo=tzutc()),
#  'name': '15 - AX BodyTRUEFIS  BH.dicom.zip',
#  'origin': {'id': 'Xuchu_Liu@rush.edu',
#             'method': None,
#             'name': None,
#             'type': 'user',
#             'via': None},
#  'parent_ref': {'id': '61f008e591188d92013e6c3b', 'type': 'acquisition'},
#  'parents': {'acquisition': '61f008e591188d92013e6c3b',
#              'analysis': None,
#              'group': 'fetal',
#              'project': '61b7a25aece9fa9a563d3d26',
#              'session': '61f008e591188d92013e6c34',
#              'subject': '61f008e591188d92013e6c33'},
#  'provider_id': '614cc33343a9d5a4ec99f8e6',
#  'replaced': None,
#  'size': 5719154,
#  'tags': [],
#  'type': 'dicom',
#  'version': 1,
#  'zip_member_count': 20}
# {'classification': {},
#  'created': datetime.datetime(2022, 1, 25, 14, 27, 53, 897000, tzinfo=tzutc()),
#  'deid_log_id': None,
#  'file_id': '61f008e991188d92013e6c5b',
#  'hash': None,
#  'id': '0a36870b-ec40-40b8-b00e-b31e02a34b26',
#  'info': {},
#  'info_exists': True,
#  'mimetype': 'application/octet-stream',
#  'modality': 'MR',
#  'modified': datetime.datetime(2022, 1, 25, 14, 30, 43, 475000, tzinfo=tzutc()),
#  'name': '16 - COR BodyTRUEFIS BH.dicom.zip',
#  'origin': {'id': 'Xuchu_Liu@rush.edu',
#             'method': None,
#             'name': None,
#             'type': 'user',
#             'via': None},
#  'parent_ref': {'id': '61f008e691188d92013e6c3c', 'type': 'acquisition'},
#  'parents': {'acquisition': '61f008e691188d92013e6c3c',
#              'analysis': None,
#              'group': 'fetal',
#              'project': '61b7a25aece9fa9a563d3d26',
#              'session': '61f008e591188d92013e6c34',
#              'subject': '61f008e591188d92013e6c33'},
#  'provider_id': '614cc33343a9d5a4ec99f8e6',
#  'replaced': None,
#  'size': 4592817,
#  'tags': [],
#  'type': 'dicom',
#  'version': 1,
#  'zip_member_count': 18}
# {'classification': {},
#  'created': datetime.datetime(2022, 1, 25, 14, 27, 52, 221000, tzinfo=tzutc()),
#  'deid_log_id': None,
#  'file_id': '61f008e891188d92013e6c48',
#  'hash': None,
#  'id': 'd6738e5c-7478-4d2e-84b2-b83104aad518',
#  'info': {},
#  'info_exists': True,
#  'mimetype': 'application/octet-stream',
#  'modality': 'MR',
#  'modified': datetime.datetime(2022, 1, 25, 14, 30, 36, 440000, tzinfo=tzutc()),
#  'name': '17 - COR Body TRUEFIS BH.dicom.zip',
#  'origin': {'id': 'Xuchu_Liu@rush.edu',
#             'method': None,
#             'name': None,
#             'type': 'user',
#             'via': None},
#  'parent_ref': {'id': '61f008e691188d92013e6c3d', 'type': 'acquisition'},
#  'parents': {'acquisition': '61f008e691188d92013e6c3d',
#              'analysis': None,
#              'group': 'fetal',
#              'project': '61b7a25aece9fa9a563d3d26',
#              'session': '61f008e591188d92013e6c34',
#              'subject': '61f008e591188d92013e6c33'},
#  'provider_id': '614cc33343a9d5a4ec99f8e6',
#  'replaced': None,
#  'size': 4347097,
#  'tags': [],
#  'type': 'dicom',
#  'version': 1,
#  'zip_member_count': 19}
# {'classification': {},
#  'created': datetime.datetime(2022, 1, 25, 14, 27, 54, 409000, tzinfo=tzutc()),
#  'deid_log_id': None,
#  'file_id': '61f008ea91188d92013e6c61',
#  'hash': None,
#  'id': '2cc2c5e0-6932-43cd-8325-e548bd4bc1f7',
#  'info': {},
#  'info_exists': True,
#  'mimetype': 'application/octet-stream',
#  'modality': 'MR',
#  'modified': datetime.datetime(2022, 1, 25, 14, 30, 49, 854000, tzinfo=tzutc()),
#  'name': '18 - COR BodyTRUEFIS BH.dicom.zip',
#  'origin': {'id': 'Xuchu_Liu@rush.edu',
#             'method': None,
#             'name': None,
#             'type': 'user',
#             'via': None},
#  'parent_ref': {'id': '61f008e691188d92013e6c3e', 'type': 'acquisition'},
#  'parents': {'acquisition': '61f008e691188d92013e6c3e',
#              'analysis': None,
#              'group': 'fetal',
#              'project': '61b7a25aece9fa9a563d3d26',
#              'session': '61f008e591188d92013e6c34',
#              'subject': '61f008e591188d92013e6c33'},
#  'provider_id': '614cc33343a9d5a4ec99f8e6',
#  'replaced': None,
#  'size': 4742306,
#  'tags': [],
#  'type': 'dicom',
#  'version': 1,
#  'zip_member_count': 18}
# {'classification': {'Intent': ['Structural'], 'Measurement': ['T2']},
#  'created': datetime.datetime(2022, 1, 25, 14, 27, 54, 194000, tzinfo=tzutc()),
#  'deid_log_id': None,
#  'file_id': '61f008ea91188d92013e6c5f',
#  'hash': None,
#  'id': 'b51add61-fe6a-413f-a527-a791cf570c98',
#  'info': {},
#  'info_exists': True,
#  'mimetype': 'application/octet-stream',
#  'modality': 'MR',
#  'modified': datetime.datetime(2022, 1, 25, 14, 30, 48, 958000, tzinfo=tzutc()),
#  'name': '2 - SAG BrainT2 HASTE BH.dicom.zip',
#  'origin': {'id': 'Xuchu_Liu@rush.edu',
#             'method': None,
#             'name': None,
#             'type': 'user',
#             'via': None},
#  'parent_ref': {'id': '61f008e691188d92013e6c3f', 'type': 'acquisition'},
#  'parents': {'acquisition': '61f008e691188d92013e6c3f',
#              'analysis': None,
#              'group': 'fetal',
#              'project': '61b7a25aece9fa9a563d3d26',
#              'session': '61f008e591188d92013e6c34',
#              'subject': '61f008e591188d92013e6c33'},
#  'provider_id': '614cc33343a9d5a4ec99f8e6',
#  'replaced': None,
#  'size': 5814638,
#  'tags': [],
#  'type': 'dicom',
#  'version': 1,
#  'zip_member_count': 20}
# {'classification': {'Intent': ['Structural'], 'Measurement': ['T2']},
#  'created': datetime.datetime(2022, 1, 25, 14, 27, 53, 329000, tzinfo=tzutc()),
#  'deid_log_id': None,
#  'file_id': '61f008e991188d92013e6c4d',
#  'hash': None,
#  'id': '8951528b-effb-44c5-8b49-4b66baf3c27f',
#  'info': {},
#  'info_exists': True,
#  'mimetype': 'application/octet-stream',
#  'modality': 'MR',
#  'modified': datetime.datetime(2022, 1, 25, 14, 30, 38, 94000, tzinfo=tzutc()),
#  'name': '3 - AX BrainT2 HASTE BH.dicom.zip',
#  'origin': {'id': 'Xuchu_Liu@rush.edu',
#             'method': None,
#             'name': None,
#             'type': 'user',
#             'via': None},
#  'parent_ref': {'id': '61f008e691188d92013e6c40', 'type': 'acquisition'},
#  'parents': {'acquisition': '61f008e691188d92013e6c40',
#              'analysis': None,
#              'group': 'fetal',
#              'project': '61b7a25aece9fa9a563d3d26',
#              'session': '61f008e591188d92013e6c34',
#              'subject': '61f008e591188d92013e6c33'},
#  'provider_id': '614cc33343a9d5a4ec99f8e6',
#  'replaced': None,
#  'size': 6106622,
#  'tags': [],
#  'type': 'dicom',
#  'version': 1,
#  'zip_member_count': 20}
# {'classification': {'Intent': ['Structural'], 'Measurement': ['T2']},
#  'created': datetime.datetime(2022, 1, 25, 14, 27, 54, 141000, tzinfo=tzutc()),
#  'deid_log_id': None,
#  'file_id': '61f008ead5e18dd8fc3e6b6e',
#  'hash': None,
#  'id': '57ccef6b-b57c-4835-9b72-4386c5f1a3c4',
#  'info': {},
#  'info_exists': True,
#  'mimetype': 'application/octet-stream',
#  'modality': 'MR',
#  'modified': datetime.datetime(2022, 1, 25, 14, 30, 47, 995000, tzinfo=tzutc()),
#  'name': '4 - COR BrainT2 HASTE BH.dicom.zip',
#  'origin': {'id': 'Xuchu_Liu@rush.edu',
#             'method': None,
#             'name': None,
#             'type': 'user',
#             'via': None},
#  'parent_ref': {'id': '61f008e691188d92013e6c41', 'type': 'acquisition'},
#  'parents': {'acquisition': '61f008e691188d92013e6c41',
#              'analysis': None,
#              'group': 'fetal',
#              'project': '61b7a25aece9fa9a563d3d26',
#              'session': '61f008e591188d92013e6c34',
#              'subject': '61f008e591188d92013e6c33'},
#  'provider_id': '614cc33343a9d5a4ec99f8e6',
#  'replaced': None,
#  'size': 5747333,
#  'tags': [],
#  'type': 'dicom',
#  'version': 1,
#  'zip_member_count': 20}
# {'classification': {'Intent': ['Localizer'], 'Measurement': ['T2']},
#  'created': datetime.datetime(2022, 1, 25, 14, 27, 54, 88000, tzinfo=tzutc()),
#  'deid_log_id': None,
#  'file_id': '61f008ea91188d92013e6c5d',
#  'hash': None,
#  'id': '0e1dfc85-2572-47c8-93e1-c7da1d8bc8e6',
#  'info': {},
#  'info_exists': True,
#  'mimetype': 'application/octet-stream',
#  'modality': 'MR',
#  'modified': datetime.datetime(2022, 1, 25, 14, 30, 47, 126000, tzinfo=tzutc()),
#  'name': '5 - Scout Expiration BH.dicom.zip',
#  'origin': {'id': 'Xuchu_Liu@rush.edu',
#             'method': None,
#             'name': None,
#             'type': 'user',
#             'via': None},
#  'parent_ref': {'id': '61f008e691188d92013e6c42', 'type': 'acquisition'},
#  'parents': {'acquisition': '61f008e691188d92013e6c42',
#              'analysis': None,
#              'group': 'fetal',
#              'project': '61b7a25aece9fa9a563d3d26',
#              'session': '61f008e591188d92013e6c34',
#              'subject': '61f008e591188d92013e6c33'},
#  'provider_id': '614cc33343a9d5a4ec99f8e6',
#  'replaced': None,
#  'size': 4069950,
#  'tags': [],
#  'type': 'dicom',
#  'version': 1,
#  'zip_member_count': 18}
# {'classification': {'Intent': ['Structural'], 'Measurement': ['T2']},
#  'created': datetime.datetime(2022, 1, 25, 14, 27, 53, 865000, tzinfo=tzutc()),
#  'deid_log_id': None,
#  'file_id': '61f008e991188d92013e6c59',
#  'hash': None,
#  'id': 'beadb03f-af4b-4086-b6ee-3503cc6e1efb',
#  'info': {},
#  'info_exists': True,
#  'mimetype': 'application/octet-stream',
#  'modality': 'MR',
#  'modified': datetime.datetime(2022, 1, 25, 14, 30, 42, 553000, tzinfo=tzutc()),
#  'name': '6 - Sag Spine T2 HASTE BH.dicom.zip',
#  'origin': {'id': 'Xuchu_Liu@rush.edu',
#             'method': None,
#             'name': None,
#             'type': 'user',
#             'via': None},
#  'parent_ref': {'id': '61f008e691188d92013e6c43', 'type': 'acquisition'},
#  'parents': {'acquisition': '61f008e691188d92013e6c43',
#              'analysis': None,
#              'group': 'fetal',
#              'project': '61b7a25aece9fa9a563d3d26',
#              'session': '61f008e591188d92013e6c34',
#              'subject': '61f008e591188d92013e6c33'},
#  'provider_id': '614cc33343a9d5a4ec99f8e6',
#  'replaced': None,
#  'size': 5287836,
#  'tags': [],
#  'type': 'dicom',
#  'version': 1,
#  'zip_member_count': 20}
# {'classification': {'Intent': ['Structural'], 'Measurement': ['T2']},
#  'created': datetime.datetime(2022, 1, 25, 14, 27, 53, 767000, tzinfo=tzutc()),
#  'deid_log_id': None,
#  'file_id': '61f008e991188d92013e6c57',
#  'hash': None,
#  'id': 'c5902230-19b3-437b-8279-4cbe24f359eb',
#  'info': {},
#  'info_exists': True,
#  'mimetype': 'application/octet-stream',
#  'modality': 'MR',
#  'modified': datetime.datetime(2022, 1, 25, 14, 30, 41, 562000, tzinfo=tzutc()),
#  'name': '7 - SAG BrainT2 HASTE BH.dicom.zip',
#  'origin': {'id': 'Xuchu_Liu@rush.edu',
#             'method': None,
#             'name': None,
#             'type': 'user',
#             'via': None},
#  'parent_ref': {'id': '61f008e691188d92013e6c44', 'type': 'acquisition'},
#  'parents': {'acquisition': '61f008e691188d92013e6c44',
#              'analysis': None,
#              'group': 'fetal',
#              'project': '61b7a25aece9fa9a563d3d26',
#              'session': '61f008e591188d92013e6c34',
#              'subject': '61f008e591188d92013e6c33'},
#  'provider_id': '614cc33343a9d5a4ec99f8e6',
#  'replaced': None,
#  'size': 5636631,
#  'tags': [],
#  'type': 'dicom',
#  'version': 1,
#  'zip_member_count': 18}
# {'classification': {'Intent': ['Structural'], 'Measurement': ['T2']},
#  'created': datetime.datetime(2022, 1, 25, 14, 27, 53, 424000, tzinfo=tzutc()),
#  'deid_log_id': None,
#  'file_id': '61f008e991188d92013e6c4f',
#  'hash': None,
#  'id': '08f88f0c-c60a-42cb-a39e-d45baa152ff6',
#  'info': {},
#  'info_exists': True,
#  'mimetype': 'application/octet-stream',
#  'modality': 'MR',
#  'modified': datetime.datetime(2022, 1, 25, 14, 30, 38, 982000, tzinfo=tzutc()),
#  'name': '8 - Sag Spine T2 HASTE BH.dicom.zip',
#  'origin': {'id': 'Xuchu_Liu@rush.edu',
#             'method': None,
#             'name': None,
#             'type': 'user',
#             'via': None},
#  'parent_ref': {'id': '61f008e691188d92013e6c45', 'type': 'acquisition'},
#  'parents': {'acquisition': '61f008e691188d92013e6c45',
#              'analysis': None,
#              'group': 'fetal',
#              'project': '61b7a25aece9fa9a563d3d26',
#              'session': '61f008e591188d92013e6c34',
#              'subject': '61f008e591188d92013e6c33'},
#  'provider_id': '614cc33343a9d5a4ec99f8e6',
#  'replaced': None,
#  'size': 3755447,
#  'tags': [],
#  'type': 'dicom',
#  'version': 1,
#  'zip_member_count': 14}
# {'classification': {'Intent': ['Structural'], 'Measurement': ['T2']},
#  'created': datetime.datetime(2022, 1, 25, 14, 27, 53, 688000, tzinfo=tzutc()),
#  'deid_log_id': None,
#  'file_id': '61f008e907b3634c5f3e69d1',
#  'hash': None,
#  'id': '956a59fd-9714-402f-8a31-433e192fbf01',
#  'info': {},
#  'info_exists': True,
#  'mimetype': 'application/octet-stream',
#  'modality': 'MR',
#  'modified': datetime.datetime(2022, 1, 25, 14, 30, 40, 669000, tzinfo=tzutc()),
#  'name': '9 - COR Spine T2 HASTE BH.dicom.zip',
#  'origin': {'id': 'Xuchu_Liu@rush.edu',
#             'method': None,
#             'name': None,
#             'type': 'user',
#             'via': None},
#  'parent_ref': {'id': '61f008e691188d92013e6c46', 'type': 'acquisition'},
#  'parents': {'acquisition': '61f008e691188d92013e6c46',
#              'analysis': None,
#              'group': 'fetal',
#              'project': '61b7a25aece9fa9a563d3d26',
#              'session': '61f008e591188d92013e6c34',
#              'subject': '61f008e591188d92013e6c33'},
#  'provider_id': '614cc33343a9d5a4ec99f8e6',
#  'replaced': None,
#  'size': 3653670,
#  'tags': [],
#  'type': 'dicom',
#  'version': 1,
#  'zip_member_count': 14}

# %%
group = exam_000006_session.parents.group

# %%
group
# Out:
# 'fetal'
